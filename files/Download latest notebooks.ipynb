# %% [markdown]
# # Download latest notebooks
# Run this notebook to download the latest notebooks associated with this CellOrganizer release.

# %%
from cellorganizer.tools import download_latest_notebooks
download_latest_notebooks()
