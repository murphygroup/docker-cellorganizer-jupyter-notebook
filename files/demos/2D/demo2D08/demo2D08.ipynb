# %% [markdown]
# # demo2D08
# Makes a shape space plot from a PCA model.
#
# ## Input
# * a generative model
#
# ## Output
# * a valid SLML model file
# * a shape space plot

# %%
from cellorganizer.tools import img2slml, slml2info
import glob
import urllib.request
import tarfile 
import os

slml2info({'/home/murphylab/cellorganizer/models/2D/endosome.mat'}, {})
